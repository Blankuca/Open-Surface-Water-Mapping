# %%
import Dataframe
import Vector
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def show_img(dic, band):
    s = np.array(dic['df'][band]).reshape(dic['dim'])
    plt.imshow(s, cmap = 'terrain')
    plt.colorbar()
    
    return s

def threshold(band, dim):
    if band.name == 'NDVI':
        thr_band = np.array([0 if (i > 0) else 1 for i in band]).reshape(dim)
    else:
        thr_band = np.array([1 if (i > 0) else 0 for i in band]).reshape(dim)
    plt.figure()
    plt.imshow(thr_band, cmap = 'Blues')
    
    return thr_band

# %%
filepath = "../Sentinel-2/Multi-size Mosaic_resampled.tif"
test_07012020 = Dataframe.main(filepath)

# %%
water_path = "../Sentinel-2/07-01-2020/Shapefiles/Water_Polygon.shp"
water_07012020 = Vector.dataset(water_path, filepath)

# %%
ground_path = "../Sentinel-2/07-01-2020/Shapefiles/Earth_Polygon.shp"
ground_07012020 = Vector.dataset(ground_path, filepath)

# %%
ndwi = show_img(test_07012020, 'NDWI')
t_ndwi = threshold(test_07012020['df']['NDWI'], test_07012020['dim'] )

# %%
show_img(water_07012020, 'B1');

# %%
show_img(ground_07012020, 'B1');

# %%
Y = Vector.training(ground_07012020,water_07012020)

# %%
from sklearn.linear_model import LogisticRegression

df = Y['df']
LogReg=LogisticRegression()
LogReg.fit(df[['B1','B2','B3','B4','B5','B6','B7','B8','B9','B10','B11','B12','B13']], df['Content'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
t = test_07012020['df'][['B1','B2','B3','B4','B5','B6','B7','B8','B9','B10','B11','B12','B13']].fillna(0)
pred = LogReg.predict(t)

# %%
test_07012020['df']
# Out:
#           B1  B2  B3  B4  B5  B6  B7  B8  B9  B10  ...  B37  B38  B39  B40  \
# 0        NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 1        NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 2        NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 3        NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 4        NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# ...       ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 12194058 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 12194059 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 12194060 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 12194061 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
# 12194062 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  ...  NaN  NaN  NaN  NaN
#
#           B41  B42  B43  NDWI  NDVI  mNDWI
# ...

# %%
sh = pred.reshape(test_07012020['dim'])
plt.figure()
plt.imshow(sh, cmap = 'terrain')
plt.savefig('LogRegression.eps', format='eps')
